# %%
# calculadora (+,-,*)
# ToDo
# mejorar el programa con el uso del elif y else
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    elif opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    elif opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
                  
    elif opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    else:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  6
# Las opciones válidas son del 1 al 5
# Vuelve a dar tú opción
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  8
# Las opciones válidas son del 1 al 5
# Vuelve a dar tú opción
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
# calculadora (+,-,*)
# calcular el índice de masa coprporal
# mejorar el programa con el uso del elif y else
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("4.- Índice de Masa Corporal")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    elif opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    elif opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
        
    elif opcion == 4:
        print("Índice de Masa Corporal")
        w = float(input("Dame tú peso en kilogramos"))
        h = float(input("Dame tú estatura en centrímetros"))
        bmi = w / ((h/100) **2)
        print("Tú índice de masa corporal es:", bmi)
                  
    elif opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    else:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  4
# Índice de Masa Corporal
# Dame tú peso en kilogramos 82
# Dame tú estatura en centrímetros 1.75
# Tú índice de masa corporal es: 267755.1020408163
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
# calculadora (+,-,*)
# calcular el índice de masa coprporal
# mejorar el programa con el uso del elif y else
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("4.- Índice de Masa Corporal")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    elif opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    elif opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
        
    elif opcion == 4:
        print("Índice de Masa Corporal")
        w = float(input("Dame tú peso en kilogramos"))
        h = float(input("Dame tú estatura en centrímetros"))
        bmi = w / ((h/100) **2)
        print("Tú índice de masa corporal es:", bmi)
        
        if bmi < 18.5:
            print("Peso bajo, necesitas comer tacos")
        elif ( (bmi >= 18.5) and (bmi <= 24.9)):
            print("Sigue así campeón(a)")
                
    elif opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    else:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  4
# Índice de Masa Corporal
# Dame tú peso en kilogramos 70
# Dame tú estatura en centrímetros 175
# Tú índice de masa corporal es: 22.857142857142858
# Sigue así campeón(a)
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
def saludar():
    print("Hola mundo con manejo de funciones")

# %%
saludar()
# Out:
# Hola mundo con manejo de funciones

# %%
def saludar1(nombre):
    print("Hola: ", nombre)

# %%
saludar()
saludar1("Luz Elena")
# Out:
# Hola mundo con manejo de funciones
# Hola:  Luz Elena

# %%
def sumar(x, y):
    print("El resultado es: ", x + y)

# %%
sumar(10.2, 20.3)
# Out:
# El resultado es:  30.5

# %%
def sumar1(x, y):
    return x + y

# %%
sumar1(10.2, 20.3)
# Out:
# 30.5

# %%
res = sumar1(10.2, 20.3)
print("El resultado es: ", res)
# Out:
# El resultado es:  30.5

# %%
# https://www.tratamientoictus.com/body-mass-index-indice-de-masa-corporal-bmi/
# calculadora (+,-,*)
# calcular el índice de masa coprporal con el uso de funciones
# mejorar el programa con el uso del elif y else
# ámbito del while

def calcular_bmi(bmi):
    if bmi < 18.5:
        print("Peso bajo, necesitas comer tacos")
    elif ( (bmi >= 18.5) and (bmi <= 24.9)):
        print("Sigue así campeón(a)")
    elif ( (bmi >= 30) and (bmi <= 34.5)):
        print("Caminar todos los días unos 20,000 pasos")
    else:
        print("Caminar todos los días unos 50,000 pasos al menos")



respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("4.- Índice de Masa Corporal")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    elif opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    elif opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
        
    elif opcion == 4:
        print("Índice de Masa Corporal")
        w = float(input("Dame tú peso en kilogramos"))
        h = float(input("Dame tú estatura en centrímetros"))
        bmi = w / ((h/100) **2)
        print("Tú índice de masa corporal es:", bmi)
        # llamada a la función
        calcular_bmi(bmi)
        
    elif opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    else:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  4
# Índice de Masa Corporal
# Dame tú peso en kilogramos 82
# Dame tú estatura en centrímetros 175
# Tú índice de masa corporal es: 26.775510204081634
# Caminar todos los días unos 50,000 pasos al menos
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  4
# Índice de Masa Corporal
# Dame tú peso en kilogramos 75
# Dame tú estatura en centrímetros 175
# Tú índice de masa corporal es: 24.489795918367346
# Sigue así campeón(a)
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  4
# Índice de Masa Corporal
# Dame tú peso en kilogramos 80
# Dame tú estatura en centrímetros 175
# Tú índice de masa corporal es: 26.122448979591837
# Caminar todos los días unos 50,000 pasos al menos
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------

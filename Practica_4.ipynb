# %%
# hacer una suma
# los toma como string a y b y concatena
a = input("Dame el valor de a: ")
b = input("Dame el valor de b: ")
r = a + b
print("El resultado es: ", r)
# Out:
# Dame el valor de a:  23
# Dame el valor de b:  24
# El resultado es:  2324

# %%
print("hola " + "mundo ")
# Out:
# hola mundo

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El resultado es: ", r)
# Out:
# Dame el valor de a:  11.45
# Dame el valor de b:  21.23
# El resultado es:  32.68

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El resultado es:  %.2f " %(r) )
# Out:
# Dame el valor de a:  12.21
# Dame el valor de b:  11.20
# El resultado es:  23.41

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El %.2f resultado es:  %.2f " %(r, r) )
# Out:
# Dame el valor de a:  18.25
# Dame el valor de b:  15.20
# El 33.45 resultado es:  33.45

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El %.1f resultado es:  %.3f " %(r, r) )
# Out:
# Dame el valor de a:  13.5
# Dame el valor de b:  12.0
# El 25.5 resultado es:  25.500

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilómetros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("El valor en millas es:  %.3f " %(millas) )
# Out:
# Dame el número de kilómetros:  15
# El valor en millas es:  9.321

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilómetros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
print("%.1f Kilometro(s) equivale a: %.2f " %(k, millas) )
# Out:
# Dame el número de kilómetros:  15
# 15.0 Kilometro(s) equivale a: 9.32

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilometros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# Dame el número de kilometros:  15.1
# 15.1 Kilometro(s) equivale a: 9.38 millas

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor

# le faltan los dos puntos en el else
if millas = 10:
    print("Meta no cumplida")
else
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
#   File "<ipython-input-16-cff136281f8c>", line 9
#     if millas = 10:
#               ^
# SyntaxError: invalid syntax

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  15.5
# 15.5 Kilometro(s) equivale a: 9.63 millas
# Meta cunplida

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  15.9
# 15.9 Kilometro(s) equivale a: 9.88 millas
# Meta cunplida

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  16.2
# 16.2 Kilometro(s) equivale a: 10.07 millas
# Meta cunplida
